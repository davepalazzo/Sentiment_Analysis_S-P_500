# %%
import pandas as pd
import string
import re
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
# read in as df of top 10 companies from 2007-2017 with MDA text
df = pd.read_pickle('Top10_final.pkl')

# %%
wordnet_lemmatizer = WordNetLemmatizer()
english_stopwords = set(stopwords.words('english'))

# %%
# function removes stop words, punctuation and digits, and lemmatize the word token
def clean_message(msg):
    pattern = r'\\x[0-9]*|[^A-Za-z]+'
    letters = ['x','k','s','ex','htm']
    msg = str(msg).lower()
    msg_tokens = nltk.word_tokenize(msg)
    clean_msg_tokens = [w for w in msg_tokens if w not in english_stopwords]
    clean_msg_tokens_puct = ' '.join([re.sub(pattern,' ',w) for w in clean_msg_tokens ]).split()
    clean_msg_tokens_letters = [w for w in clean_msg_tokens_puct if w not in letters]
    lemmatized_token = [wordnet_lemmatizer.lemmatize(w) for w in  clean_msg_tokens_letters]
    return lemmatized_token

# %%
# go through the df to clean MDA text
for year in df:
    for i in range(len(df)):
        df[year].iloc[i] = df[year].iloc[i][0],clean_message(df[year].iloc[i][1])

# %%
df
# Out:
#                                                 2007  \
# 0  (EXXON MOBIL CORP, [exhibit, financial, statem...
# 1  (GENERAL ELECTRIC CO, [exhibit, financial, sec...
# 2  (MICROSOFT CORP, [management, discussion, anal...
# 3  (AT&T CORP, [ampt, annual, report, management,...
# 4  (PROCTER & GAMBLE CO, [p, g, financial, result...
# 5  (ALPHABET INC, [management, discussion, analys...
# 6  (CHEVRON CORP, [exhibit, financial, statement,...
# 7  (JOHNSON & JOHNSON, [exv, page, company, annua...
# 8  (WALMART INC, [dex, annual, report, annual, re...
# 9  (BANK OF AMERICA CORP, [management, discussion...
#
#                                                 2008  \
# 0  (EXXON MOBIL CORP, [exhibit, financial, statem...
# 1  (WALMART INC, [dex, annual, report, annual, re...
# 2  (PROCTER & GAMBLE CO, [p, g, financial, result...
# 3  (MICROSOFT CORP, [management, discussion, anal...
# 4  (AT&T CORP, [ampt, annual, report, management,...
# 5  (JOHNSON & JOHNSON, [exv, page, company, annua...
# 6  (GENERAL ELECTRIC CO, [management, discussion,...
# 7  (CHEVRON CORP, [exhibit, financial, statement,...
# 8  (PFIZER INC, [dex, portion, financial, report,...
# 9  (JPMORGAN CHASE & CO, [regulation, jpmorgan, c...
#
#                                                 2009  \
# 0  (EXXON MOBIL CORP, [exhibit, financial, statem...
# 1  (MICROSOFT CORP, [management, discussion, anal...
# 2  (WALMART INC, [dex, annual, report, annual, re...
# 3  (ALPHABET INC, [management, discussion, analys...
# 4  (APPLE INC, [management, discussion, analysis,...
# 5  (JOHNSON & JOHNSON, [exv, page, company, annua...
# 6  (PROCTER & GAMBLE CO, [p, g, financial, result...
# 7  (INTL BUSINESS MACHINES CORP, [zex, exhibit, e...
# 8  (AT&T CORP, [ampt, annual, report, management,...
# 9  (JPMORGAN CHASE & CO, [regulation, jpmorgan, c...
#
#                                                 2010  \
# 0  (EXXON MOBIL CORP, [exhibit, financial, statem...
# 1  (APPLE INC, [management, discussion, analysis,...
# 2  (MICROSOFT CORP, [management, discussion, anal...
# 3  (BERKSHIRE HATHAWAY, [management, discussion, ...
# 4  (GENERAL ELECTRIC CO, [management, discussion,...
# 5  (WALMART INC, [dex, annual, report, annual, re...
# 6  (ALPHABET INC, [management, discussion, analys...
# 7  (CHEVRON CORP, [exhibit, financial, statement,...
# 8  (INTL BUSINESS MACHINES CORP, [zex, exhibit, e...
# 9  (PROCTER & GAMBLE CO, [p, g, financial, result...
#
#                                                 2011  \
# 0  (EXXON MOBIL CORP, [exhibit, financial, statem...
# 1  (APPLE INC, [management, discussion, analysis,...
# 2  (MICROSOFT CORP, [management, discussion, anal...
# 3  (INTL BUSINESS MACHINES CORP, [zex, exhibit, e...
# 4  (CHEVRON CORP, [exhibit, financial, statement,...
# 5  (ALPHABET INC, [management, discussion, analys...
# 6  (WALMART INC, [dex, annual, report, annual, re...
# 7  (GENERAL ELECTRIC CO, [management, discussion,...
# 8  (BERKSHIRE HATHAWAY, [management, discussion, ...
# 9  (PROCTER & GAMBLE CO, [p, g, financial, result...
#
#                                                 2012  \
# 0  (APPLE INC, [management, discussion, analysis,...
# 1  (EXXON MOBIL CORP, [exhibit, financial, statem...
# 2  (MICROSOFT CORP, [management, discussion, anal...
# 3  (GENERAL ELECTRIC CO, [management, discussion,...
# 4  (INTL BUSINESS MACHINES CORP, [zex, exhibit, e...
# 5  (CHEVRON CORP, [exhibit, financial, statement,...
# 6  (JOHNSON & JOHNSON, [exv, page, company, annua...
# 7  (AT&T CORP, [ampt, annual, report, management,...
# 8  (PROCTER & GAMBLE CO, [management, discussion,...
# 9  (PFIZER INC, [dex, portion, financial, report,...
#
#                                                 2013  \
# 0  (Apple Inc., [management, discussion, analysis...
# 1  (Exxon Mobil Corp., [exhibit, financial, state...
# 2  (Alphabet Inc. Class A, [management, discussio...
# 3  (Microsoft Corp., [management, discussion, ana...
# 4  (Berkshire Hathaway Inc, [management, discussi...
# 5  (General Electric, [management, discussion, an...
# 6  (JOHNSON & JOHNSON, [exv, page, company, annua...
# 7  (Wal-Mart Stores Inc, [dex, annual, report, an...
# 8  (Chevron Corp., [exhibit, financial, statement...
# 9  (Wells Fargo, [wfc, exhibit, financial, review...
#
#                                                 2014  \
# 0  (Apple Inc., [management, discussion, analysis...
# 1  (Exxon Mobil Corp., [exhibit, financial, state...
# 2  (Microsoft Corp., [management, discussion, ana...
# 3  (Berkshire Hathaway Inc, [management, discussi...
# 4  (Alphabet Inc. Class A, [management, discussio...
# 5  (JOHNSON & JOHNSON, [exv, page, company, annua...
# 6  (Wells Fargo, [wfc, exhibit, financial, review...
# 7  (Wal-Mart Stores Inc, [dex, annual, report, an...
# 8  (General Electric, [md, management, discussion...
# 9  (Procter & Gamble, [management, discussion, an...
#
#                                                 2015  \
# 0  (Apple Inc., [management, discussion, analysis...
# 1  (Alphabet Inc. Class A, [management, discussio...
# 2  (Microsoft Corp., [management, discussion, ana...
# 3  (Berkshire Hathaway Inc, [management, discussi...
# 4  (Exxon Mobil Corp., [exhibit, financial, state...
# 5  (Amazon.com Inc., [management, discussion, ana...
# 6  (Facebook Inc., [management, discussion, analy...
# 7  (General Electric, [management, discussion, an...
# 8  (Johnson & Johnson, [management, discussion, a...
# 9  (Wells Fargo, [wfc, exhibit, financial, review...
#
#                                                 2016  \
# 0  (Apple Inc., [management, discussion, analysis...
# 1  (Alphabet Inc. Class A, [management, discussio...
# 2  (Microsoft Corp., [management, discussion, ana...
# 3  (Berkshire Hathaway Inc, [management, discussi...
# 4  (Exxon Mobil Corp., [exhibit, financial, state...
# 5  (Amazon.com Inc., [management, discussion, ana...
# 6  (Facebook Inc., [management, discussion, analy...
# 7  (Johnson & Johnson, [management, discussion, a...
# 8  (JPMorgan Chase & Co., [regulation, jpmorgan, ...
# 9  (General Electric, [management, discussion, an...
#
#                                                 2017
# 0  (Apple Inc., [management, discussion, analysis...
# 1  (Alphabet Inc. Class A, [management, discussio...
# 2  (Microsoft Corp., [management, discussion, ana...
# 3  (Amazon.com Inc., [management, discussion, ana...
# 4  (Facebook Inc., [management, discussion, analy...
# 5  (Berkshire Hathaway Inc, [management, discussi...
# 6  (Johnson & Johnson, [management, discussion, a...
# 7  (JPMorgan Chase & Co., [regulation, jpmorgan, ...
# 8  (Exxon Mobil Corp., [form, summary, none, fina...
# 9  (Bank of America Corp., [management, discussio...

# %%
# cleaned MDA text
df.to_pickle('Cleaned_MDA.pkl')
