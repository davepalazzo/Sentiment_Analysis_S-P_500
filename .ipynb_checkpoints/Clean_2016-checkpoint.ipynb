# %%
import edgar
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup as bsoup
import numpy as np

# %% [markdown]
# ## Get the annual filings for each company

# %%
comp_2016 = pd.DataFrame.from_csv('companies_2016.csv',encoding='latin-1')
comp_2016 = comp_2016[:505]
comp_2016.CIK = comp_2016['CIK'].astype(int).apply(lambda x: str(x).zfill(10))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
res = requests.get('http://siblisresearch.com/data/market-caps-sp-100-us/')
soup = bsoup(res.content,'html.parser')

# %%
def extractTable(soup): 
    table = []
    for div in soup.find_all('table', {'id':'supsystic-table-8'}):
        #for a in div.find_all('a', {'data-tn-element':'jobTitle'}):
            table+=div
    return(table)

# %%
tab = extractTable(soup)

# %%
print(type(tab))
tab
for i in tab:
    print(i.text)
# Out:
# <class 'list'>
#  Ticker  Company Name  9/30/2018  12/31/2017  12/31/2016  12/31/2015  12/31/2014  12/31/2013  AAPL  Apple Inc.  1,093,240.08  859,967.80  617,588.49  586,859.34  647,361.04  500,738.96  AMZN  Amazon.com Inc.  975,461.00  566,023.48  356,313.48  316,831.55  143,693.91  182,539.74  MSFT  Microsoft Corp.  878,018.49  659,085.70  483,160.31  443,169.41  382,880.52  312,297.48  GOOGL  Alphabet Inc. Class A  840,062.50  731,884.41  546,188.24  534,763.62  360,940.07  376,370.28  BRK.B  Berkshire Hathaway Inc  528,336.12  489,062.06  401,987.01  325,490.35  370,024.10  292,360.78  FB  Facebook Inc.  475,453.86  512,792.76  332,724.60  297,757.70  218,221.94  139,193.55  JPM  JPMorgan Chase & Co.  379,242.15  366,301.48  308,768.40  243,065.01  233,935.87  219,837.37  JNJ  Johnson & Johnson  370,613.53  374,802.39  313,432.49  284,220.49  292,702.93  258,415.51  XOM  Exxon Mobil Corp.  359,958.53  354,549.96  374,280.51  324,501.10  391,482.21  442,093.62  V  Visa Inc.  344,137.61  257,324.21  181,084.42  186,817.95  161,506.02  141,189.59  BAC  Bank of America Corp.  294,974.70  303,681.16  225,526.06  175,242.04  188,139.29  166,071.71  WMT  Wal-Mart Stores Inc  275,625.85  293,090.00  212,418.89  196,276.04  276,807.56  254,622.90  PFE  Pfizer Inc.  258,343.19  216,559.38  197,100.17  199,280.68  196,265.47  198,515.20  UNH  United Health Group Inc.  255,930.48  213,625.74  152,328.63  112,123.63  97,025.27  75,808.88  WFC  Wells Fargo  254,867.01  296,774.40  276,779.12  277,660.71  284,385.55  239,148.99  T  AT&T Inc.  243,782.57  238,700.84  261,176.73  211,690.32  174,231.33  185,222.88  HD  Home Depot  237,186.75  221,371.04  163,331.03  167,677.26  138,332.30  115,953.41  CVX  Chevron Corp.  234,306.46  238,449.64  222,190.41  169,308.05  212,067.76  240,223.54  MA  Mastercard Inc.  231,291.79  159,533.44  110,425.36  107,118.78  95,889.19  96,747.10  CSCO  Cisco Systems  224,471.10  189,340.72  151,697.12  137,866.31  142,260.02  119,924.64  VZ  Verizon Communications  220,604.06  215,926.66  217,610.72  188,063.31  194,124.09  140,540.40  INTC  Intel Corp.  218,054.19  216,351.92  171,883.53  162,569.55  175,462.15  129,047.16  BA  Boeing Co.  214,171.26  174,303.31  96,080.40  96,872.99  92,666.64  102,565.82  PG
# 16                    Home Depot   163331.03
# 26                   Merck & Co.   162312.71
# 35                     IBM Corp.   157832.42
# 24                  Oracle Corp.   157735.47
# 13      United Health Group Inc.   152328.63
# 19                 Cisco Systems   151697.12
# ..                           ...         ...
# 63                   Lowe's Cos.    61863.52
# 81             Biogen Idec, Inc.    61699.63
# 76                 BlackRock Inc    61673.74
# 99                    Chubb Ltd.    61480.59
# 78                 EOG Resources    58279.90
# 29                  Nvidia Corp.    57532.86
# 95  PNC Financial SVCS Group Inc    56901.27
# 41           Abbott Laboratories    56551.43
# 73                NextEra Energy    55819.84
# 60      Thermo Fisher Scientific    55738.03
# 98          Occidental Petroleum    54433.11
# 65              Caterpillar Inc.    54259.67
# 75                 Danaher Corp.    53842.08
# 30                  Netflix Inc.    53128.15
# 87          Charles Schwab Corp.    52324.27
# 68      Twenty-First Century Fox    51897.40
# 39            Adobe Systems Inc.    50883.45
# 93             FedEx Corporation    49623.98
# 83            TJX Companies Inc.    48977.32
# 53          PayPal Holdings Inc.    47626.32
# 46                Salesforce.com    46490.78
# 88                     ADP, LLC.    46371.56
# 91          American Tower Corp.    44992.52
# 85                 Stryker Corp.    44863.09
# 86                    Aetna Inc.    43515.11
# 80                   Anthem Inc.    37874.05
# 82         Becton Dickinson & Co    35300.56
# 92                     CSX Corp.    33654.23
# 94       Activision Blizzard Inc    26837.42
# 89       Intuitive Surgical Inc.    24572.18
#
# [100 rows x 2 columns]

# %%
comp_2016
# Out:
#       2018  Unnamed: 2                            Security Symbol SEC filings  \
# 2017
# NaN    NaN           0                          3M Company    MMM     reports
# NaN    NaN           1                 Abbott Laboratories    ABT     reports
# NaN    NaN           2                         AbbVie Inc.   ABBV     reports
# NaN   ABMD           3                   Wyndam Worldwide     WYN     reports
# NaN    NaN           4                       Accenture plc    ACN     reports
# NaN    NaN           5                 Activision Blizzard   ATVI     reports
# NaN    NaN           6                   Adobe Systems Inc   ADBE     reports
# AMD    NaN           7                     Urban Outfilers   URBN         NaN
# NaN    NaN           8                  Advance Auto Parts    AAP     reports
# NaN    NaN           9                            AES Corp    AES     reports
# NaN    NaN          10       Affiliated Managers Group Inc    AMG     reports
# NaN    NaN          11                           AFLAC Inc    AFL     reports
# NaN    NaN          12            Agilent Technologies Inc      A     reports
# NaN    NaN          13        Air Products & Chemicals Inc    APD     reports
# NaN    NaN          14             Akamai Technologies Inc   AKAM     reports
# NaN    NaN          15                Alaska Air Group Inc    ALK     reports
# NaN    NaN          16                      Albemarle Corp    ALB     reports
# ARE    NaN          17                         First Solar   FSLR     reports
# NaN    NaN          18             Alexion Pharmaceuticals   ALXN     reports
# ALGN   NaN          19                       Terdata Corp.    TDC     reports
# NaN    NaN          20                            Allegion   ALLE     reports
# NaN    NaN          21                       Allergan, Plc    AGN     reports
# NaN    NaN          22               Alliance Data Systems    ADS     reports
# NaN    NaN          23                 Alliant Energy Corp    LNT     reports
# NaN    NaN          24                       Allstate Corp    ALL     reports
# NaN    NaN          25                Alphabet Inc Class A  GOOGL     reports
# NaN    NaN          26                Alphabet Inc Class C   GOOG     reports
# NaN    NaN          27                    Altria Group Inc     MO     reports
# NaN    NaN          28                     Amazon.com Inc.   AMZN     reports
# NaN    NaN          29                         Ameren Corp    AEE     reports
# ...    ...         ...                                 ...    ...         ...
# NaN    NaN         475                         Viacom Inc.   VIAB     reports
# NaN    NaN         476                           Visa Inc.      V     reports
# NaN    NaN         477                Vornado Realty Trust    VNO     reports
# NaN    NaN         478                    Vulcan Materials    VMC     reports
# NaN    WAB         479  The Goodyear Tire & Rubber Company     GT     reports
# NaN    NaN         480                             Walmart    WMT     reports
# NaN    NaN         481            Walgreens Boots Alliance    WBA     reports
# NaN    NaN         482             The Walt Disney Company    DIS     reports
# NaN    NaN         483               Waste Management Inc.     WM     reports
# NaN    NaN         484                  Waters Corporation    WAT     reports
# NaN    NaN         485                Wec Energy Group Inc    WEC     reports
# NaN    wcg         486                            XL Group     XL     reports
# NaN    NaN         487                         Wells Fargo    WFC     reports
# NaN    NaN         488                      Welltower Inc.   WELL     reports
# NaN    NaN         489                     Western Digital    WDC     reports
# NaN    NaN         490                    Western Union Co     WU     reports
# NaN    NaN         491                            WestRock    WRK     reports
# NaN    NaN         492                        Weyerhaeuser     WY     reports
# NaN    NaN         493                     Whirlpool Corp.    WHR     reports
# NaN    NaN         494                       Williams Cos.    WMB     reports
# NaN    NaN         495                Willis Towers Watson   WLTW     reports
# NaN    NaN         496                    Wynn Resorts Ltd   WYNN     reports
# NaN    NaN         497                     Xcel Energy Inc    XEL     reports
# NaN    NaN         498                               Xerox    XRX     reports
# NaN    NaN         499                              Xilinx   XLNX     reports
# NaN    NaN         500                          Xylem Inc.    XYL     reports
# NaN    NaN         501                     Yum! Brands Inc    YUM     reports
# NaN    NaN         502              Zimmer Biomet Holdings    ZBH     reports
# NaN    NaN         503                       Zions Bancorp   ZION     reports
# NaN    NaN         504                              Zoetis    ZTS     reports
#
#                  GICS Sector                             GICS Sub Industry  \
# 2017
# NaN              Industrials                      Industrial Conglomerates
# NaN              Health Care                         Health Care Equipment
# NaN              Health Care                               Pharmaceuticals
# NaN                      NaN                                           NaN
# NaN   Information Technology                IT Consulting & Other Services
# NaN   Communication Services                Interactive Home Entertainment
# NaN   Information Technology                          Application Software
# AMD                      NaN                                           NaN
# NaN   Consumer Discretionary                             Automotive Retail
# NaN                Utilities  Independent Power Producers & Energy Traders
# NaN               Financials              Asset Management & Custody Banks
# NaN               Financials                       Life & Health Insurance
# NaN              Health Care                         Health Care Equipment
# NaN                Materials                              Industrial Gases
# NaN   Information Technology            Internet Services & Infrastructure
# NaN              Industrials                                      Airlines
# NaN                Materials                           Specialty Chemicals
# ARE                      NaN                                           NaN
# NaN              Health Care                                 Biotechnology
# ALGN                     NaN                                           NaN
# NaN              Industrials                             Building Products
# NaN              Health Care                               Pharmaceuticals
# NaN   Information Technology         Data Processing & Outsourced Services
# NaN                Utilities                            Electric Utilities
# NaN               Financials                 Property & Casualty Insurance
# NaN   Communication Services                  Interactive Media & Services
# NaN   Communication Services                  Interactive Media & Services
# NaN         Consumer Staples                                       Tobacco
# NaN   Consumer Discretionary            Internet & Direct Marketing Retail
# NaN                Utilities                               Multi-Utilities
# ...                      ...                                           ...
# NaN   Communication Services                        Movies & Entertainment
# NaN   Information Technology                                   IT Services
# NaN              Real Estate                                  Office REITs
# NaN                Materials                        Construction Materials
# NaN             Deerfield, Illinois            29220  0001618921          NaN
# NaN             Burbank, California            27941  0001001039          NaN
# NaN                  Houston, Texas              NaN  0000823768         1968
# NaN          Milford, Massachusetts              NaN  0001000697         1958
# NaN            Milwaukee, Wisconsin            39752  0000783325          NaN
# NaN                             NaN              NaN  0000875159          NaN
# NaN       San Francisco, California            27941  0000072971          NaN
# NaN                    Toledo, Ohio            39843  0000766704          NaN
# NaN              Irvine, California            39995  0000106040          NaN
# NaN             Englewood, Colorado              NaN  0001365135         1851
# NaN              Richmond, Virginia              NaN  0001636023          NaN
# NaN         Federal Way, Washington              NaN  0000106535          NaN
# NaN         Benton Harbor, Michigan              NaN  0000106640         1911
# NaN                 Tulsa, Oklahoma            27484  0000107263          NaN
# NaN          London, United Kingdom            42374  0001140536          NaN
# NaN                Paradise, Nevada            39766  0001174922          NaN
# NaN          Minneapolis, Minnesota              NaN  0000072903         1909
# NaN            Norwalk, Connecticut              NaN  0000108772         1906
# NaN            San Jose, California            36472  0000743988          NaN
# NaN          White Plains, New York            40848  0001524472          NaN
# NaN            Louisville, Kentucky            35709  0001041061          NaN
# NaN                 Warsaw, Indiana            37110  0001136869          NaN
# NaN            Salt Lake City, Utah            37064  0000109380          NaN
# NaN        Florham Park, New Jersey            41446  0001555280          NaN
#
#       Unnamed: 12  Unnamed: 13
# 2017
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# AMD           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# ARE           NaN          NaN
# NaN           NaN          NaN
# ALGN          NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# ...           ...          ...
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
# NaN           NaN          NaN
#
# [505 rows x 13 columns]

# %%
df_2016_top = df_2016.nlargest(25,columns='12/31/2016')

# %%
df_2016_top['Company Name']
# Out:
# 0                 Apple Inc.
# 3      Alphabet Inc. Class A
# 2            Microsoft Corp.
# 4     Berkshire Hathaway Inc
# 8          Exxon Mobil Corp.
# 1            Amazon.com Inc.
# 5              Facebook Inc.
# 7          Johnson & Johnson
# 6       JPMorgan Chase & Co.
# 61          General Electric
# 14               Wells Fargo
# 15                 AT&T Inc.
# 10     Bank of America Corp.
# 23          Procter & Gamble
# 17             Chevron Corp.
# 20    Verizon Communications
# 11       Wal-Mart Stores Inc
# 12               Pfizer Inc.
# 9                  Visa Inc.
# 25         The Coca Cola Co.
# 21               Intel Corp.
# 27            Citigroup Inc.
# 28       The Walt Disney Co.
# 31     Comcast Class A Comm.
# 16                Home Depot
# Name: Company Name, dtype: object

# %%
df_2016_top.reset_index(drop=True, inplace=True)

# %%
from collections import defaultdict
cikDict = defaultdict
for i in range(len(df_2016_top)):
    for j in range(len(comp_2016['Security'])):
        
        if df_2016_top['Company Name'][i] == comp_2016['Security'][j]:
            cikDict[i] += comp_2016['CIK'][j]
#         else:
#             cikDict += None
# for comp in df_2016_top['Company Name']:
#     if comp in comp_2016['Security']:
#         cikDict +=
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-e86a5eb33b0e> in <module>
#       5
#       6         if df_2016_top['Company Name'][i] == comp_2016['Security'][j]:
# ----> 7             cikDict[i] += str(comp_2016['CIK'][j])
#       8 #         else:
#       9 #             cikDict += None
#
# TypeError: 'type' object is not subscriptable

# %%
comp_2016['CIK'][1]
# Out:
# '0000001800'

# %%
data1 = pd.read_html(tab,skiprows=1)[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-827bf7f4f117> in <module>
# ----> 1 data1 = pd.read_html(tab,skiprows=1)[0]
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     914             break
#     915     else:
# --> 916         raise_with_traceback(retained)
#     917
#     918     ret = []
#
# /anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#     418         if traceback == Ellipsis:
#     419             _, _, traceback = sys.exc_info()
# --> 420         raise exc.with_traceback(traceback)
#     421 else:
#     422     # this version of raise is a syntax error in Python 3
#
# TypeError: Cannot read object of type 'list'

# %%
comp = comp_2016[:50]

# %%
company = edgar.Company('ATVI','0000718877')
tree = company.getAllFilings(filingType = "10-K")
doc = edgar.getDocuments(tree, noOfDocuments=3)

# %% [markdown]
# ## 2016

# %%
def annual_filings(name,ID):
    '''This function finds the correct document'''
    # get filings from package
    company = edgar.Company(name,ID)
    tree = company.getAllFilings(filingType = "10-K")
    doc = edgar.getDocuments(tree, noOfDocuments=4)
    
    # if compnay only has one document
    #if len(doc) > 3:
        #return None
    
    # search for the right document year 
    d = 1
    while d < len(doc):
    
        filing = (re.sub('\\xa0|\\n',' ',doc[d]))
        filingShort = filing[:1000]
        # see if the document is amended
        if '10-K/A' in filing[1:15]:
            d += 1
    
        # if in the right fiscal year and remove the new lines and break
        elif re.search(r'FOR THE FISCAL YEAR ENDED\s*[0-9]*\s*[A-Z]*\s*2016|FOR THE\s*(FISCAL)? YEAR ENDED\s*(Commission File Number)?\W?\s*[A-Z]*\s*[0-9]*,\s*2017',filingShort,re.IGNORECASE):
            filing = filing.replace('\n', '').replace('\t', '').replace('\r','').replace('Contents',' ').upper().split('ITEM ')
            break
        
        elif re.search(r'FOR THE FISCAL YEAR ENDED\s*[0-9]*\s*[A-Z]*\s*2018|FOR THE\s*(FISCAL)? YEAR ENDED\s*(Commission File Number)?\W?\s*[A-Z]*\s*[0-9]*,\s*2018',filingShort,re.IGNORECASE):
            d += 1
        
        elif re.search(r'FOR THE FISCAL YEAR ENDED\s*[0-9]*\s*[A-Z]*\s*2017|FOR THE\s*(FISCAL)? YEAR ENDED\s*(Commission File Number)?\W?\s*[A-Z]*\s*[0-9]*,\s*2016',filingShort,re.IGNORECASE):
            d += 1
            
        elif re.search(r'FOR THE FISCAL YEAR ENDED\s*[0-9]*\s*[A-Z]*\s*2015|FOR THE\s*(FISCAL)? YEAR ENDED\s*(Commission File Number)?\W?\s*[A-Z]*\s*[0-9]*,\s*2016',filingShort,re.IGNORECASE):
            d += 1
        else:
            return None

    new_doc = []
    start = []
    stop = []
    # remove characters from filing
    for item in filing:
        new_doc.append(re.sub('\\xa0*|(?<=[7-8])\W?s?','',item))
    for i in range(len(new_doc)):
        if re.search(r'7\s*\W?\.?\s*(AND 7A.)?(COMBINED)?\s*MANAGEMENT\W?\s*S\s*DISCUSSION\s*AND\s*ANALYSIS\s*OF\s*(CONSOLIDATED)?\s*FINANCIAL\s*CONDITION\S?\s*AND\s*RESULTS\s*OF\s*OPERATION\S?',new_doc[i]):
            start.append(i)
        if re.search(r'7\s*\W?\.?\s*MANAGEMENT\W?\s*S\s*DISCUSSION\s*AND\s*ANALYSIS\s*OF\s*RESULTS\s*OF\s*OPERATIONS\s*AND\s*FINANCIAL\s*CONDITION',new_doc[i]):
            start.append(i)
        #if re.search(r'8\s*\W?\w?\.?\s*(CONSOLIDATED)?(COMCAST CORPORATION)?\s*FINANCIAL\s*STATEMENTS\s*AND\s*SUPPLEMENTA\w*\s*DATA',new_doc[i]):
            #stop.append(i)     
        if re.search(r'9\s*\W?\w?\.?\s*CONTROLS\s*AND\s*PROCEDURES',new_doc[i]):
            stop.append(i) 
    
    
#     for i in range(len(new_doc)):
#         if len(stop) == 0 and len(start) > 0:
#             if re.search(r'8\s*\W?\w?\.?\s*FINANCIAL\s*STATEMENTS',new_doc[i]):
#                 stop = [i]
#             if re.search(r'9\s*\W?\w?\.?\s*CONTROLS\s*AND\s*PROCEDURES',new_doc[i]):
#                 stop = [i]
    
    return name,ID,start,stop,d

# %%
MDAFCRO_index = []
# go through each company add get the indices of which section to pull the MDA from
for i in range(len(comp)):
    MDAFCRO_index.append(annual_filings(comp.iloc[i].Security,str(comp.iloc[i].CIK)))

# %%
MDAFCRO_index
# Out:
# [('3M Company', '0000066740', [11, 29, 31, 42], [16, 64], 1),
#  ('Abbott Laboratories', '0000001800', [6, 15], [22], 1),
#  ('AbbVie Inc.', '0001551152', [10, 24, 29, 36, 38, 47, 48], [14, 56], 1),
#  ('Wyndam Worldwide ', '0001361658', [10, 31], [14, 35], 1),
#  ('Accenture plc', '0001467373', [10, 33], [14, 62], 1),
#  ('Activision Blizzard', '0000718877', [10, 25, 27, 28, 29, 42], [14, 55], 1),
#  ('Adobe Systems Inc', '0000796343', [10, 34, 35], [14, 44], 1),
#  ('Advanced Micro Devices Inc',
#   '0000002488',
#   [10, 25, 26, 27, 36],
#   [14, 45],
#   1),
#  ('Advance Auto Parts', '0001158449', [10, 30], [14, 35], 1),
#  ('AES Corp',
#   '0000874761',
#   [10,
#    27,
#    29,
#    36,
#    37,
#    38,
#    39,
#    42,
#    43,
#    47,
#    51,
#    53,
#    55,
#    56,
#    59,
#    60,
#    68,
#    78,
#    85,
#    86],
#   [14, 140],
#   1),
#  ('Affiliated Managers Group Inc', '0001004434', [10, 36], [14, 44], 3),
#  ('AFLAC Inc', '0000004977', [10, 39], [14, 65], 1),
#  ('Agilent Technologies Inc', '0001090872', [10, 32], [14, 44], 1),
#  ('Air Products & Chemicals Inc', '0000002969', [10, 37], [14, 43], 2),
#  ('Akamai Technologies Inc', '0001086222', [10, 31], [14, 37], 1),
#  ('Alaska Air Group Inc', '0000766421', [10, 31], [14, 36], 1),
#  ('Albemarle Corp', '0000915913', [10, 27, 31, 40], [14, 54], 1),
#  ('Alexandria Real Estate Equities',
#   '0001035443',
#   [10, 23, 26, 28, 33, 34, 37, 41, 62],
#   [14, 122],
#   1),
#  ('Alexion Pharmaceuticals', '0000899866', [10, 35, 36], [14, 47], 1),
#  ('Align Technology', '0001097149', [10, 38], [14, 48], 1),
#  ('Allegion', '0001579241', [10, 35], [14, 42], 1),
#  ('Allergan, Plc', '0001578845', [10, 44, 46, 47, 48], [14, 60], 1),
#  ('Alliance Data Systems', '0001101215', [2, 12, 13], [2, 17], 1),
#  ('Alliant Energy Corp', '0000352541', [10, 34], [14, 47], 1),
#  ('Allstate Corp', '0000899051', [10, 35, 36, 71], [14, 97, 99], 1),
#  ('Alphabet Inc Class A', '0001652044', [11, 26, 38, 40], [15, 55], 2),
#  ('Alphabet Inc Class C', '0001652044', [11, 26, 38, 40], [15, 55], 2),
#  ('Altria Group Inc', '0000764180', [10, 30, 65], [14, 93], 2),
#  ('Amazon.com Inc.', '0001018724', [10, 46], [14, 68], 1),
#  ('Ameren Corp', '0001002910', [11, 60], [15, 124], 1),
#  ('American Airlines Group', '0000006201', [10, 24, 28, 32, 65], [15, 115], 1),
#  ('American Electric Power', '0000004904', [3, 4, 23], [3, 32], 1),
#  ('American Express Co', '0000004962', [2, 11], [2, 22], 1),
#  ('American International Group',
#   '0000005272',
#   [12, 26, 95, 97, 243],
#   [16],
#   1),
#  ('American Tower Corp.', '0001053507', [10, 37], [14, 47], 1),
#  ('American Water Works Company Inc',
#   '0001410636',
#   [10, 25, 29, 30, 43, 45],
#   [14, 56],
#   1),
#  ('Ameriprise Financial', '0000820027', [10, 56], [14, 70], 1),
#  ('AmerisourceBergen Corp', '0001140859', [2, 13], [2, 21], 1),
#  ('AMETEK Inc.', '0001037868', [9, 22, 23, 26, 32, 36], [13, 60], 1),
#  ('Amgen Inc.', '0000318154', [10, 43, 55, 56], [14, 76], 1),
#  ('Amphenol Corp', '0000820313', [10, 41], [14, 59], 1),
#  ('Anadarko Petroleum Corp', '0000773910', [8, 47], [12, 93], 1),
#  ('Analog Devices, Inc.', '0000006281', [10, 40], [14, 57], 1),
#  ('ANSYS', '0001013462', [10, 42], [14, 56], 1),
#  ('Anthem Inc.', '0001156039', [10, 23, 31, 33, 57, 58, 91], [14, 102], 1),
#  ('Aon plc', '0000315293', [10, 37], [14, 50], 1),
#  ('A.O. Smith Corp', '0000091142', [10, 37], [14], 1),
#  ('Apache Corporation', '0000006769', [2, 4, 6, 7, 9, 21], [2, 43], 1),
#  ('Apartment Investment & Management', '0000922864', [3, 28], [2, 3, 50], 1),
#  ('Apple Inc.', '0000320193', [10, 32, 41, 43], [14, 62], 1)]

# %%
def MDA(name,ID,start_index,stop_index,doc_num):
    '''This function returns the MDA text of the 10-k filing using the indices provided and the correct document.'''
    # get filings from package
    company = edgar.Company(name,ID)
    tree = company.getAllFilings(filingType = "10-K")
    doc = edgar.getDocuments(tree, noOfDocuments=doc_num+1)
    
    # create the same format used from the function above
    filing = (re.sub('\\xa0|\\n',' ',doc[doc_num]))
    filing = filing.replace('\n', '').replace('\t', '').replace('\r','').replace('Contents',' ').upper().split('ITEM ')
    new_doc = []
    for item in filing:
        new_doc.append(re.sub('\\xa0*|(?<=[7-8])\W?s?','',item))
    
    # find the text using the indices
    MDA_text = []
    
    return name,ID,MDA_text

# %%
MDAFCRO = []
for i in MDAFCRO_index:
    if i != None:
        MDAFCRO.append(MDA(i[0],i[1],i[2],i[3],i[4]))
    else:
        pass
